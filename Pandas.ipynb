# %% [markdown]
# <a href="https://colab.research.google.com/github/litlife8582/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a pandas list

# %%
my_series=[5,9,12,27]
my_var=pd.Series(my_series)
my_var
# Out:
# 0     5
# 1     9
# 2    12
# 3    27
# dtype: int64

# %%
my_var[2]
# Out:
# np.int64(12)

# %% [markdown]
# Putting index to out data values

# %%
my_index=["A","B","C","D"]
my_var2=pd.Series(my_series,my_index)
my_var2
# Out:
# A     5
# B     9
# C    12
# D    27
# dtype: int64

# %%
my_var2["B"]
# Out:
# np.int64(9)

# %% [markdown]
# Using python dictionary

# %%
cars={"Tesla":12,
      "Mercedes":42,
      "BMW":3}

my_var3=pd.Series(cars)
my_var3
# Out:
# Tesla       12
# Mercedes    42
# BMW          3
# dtype: int64

# %% [markdown]
# Data Frames

# %% [markdown]
# Creating data frame makes it easier to visualize data

# %%
from numpy.random import random #creates random data

# %%
my_data=random((4,3))
my_rows=["A","B","C","D"]
my_columns=["Monday","Tuesday","Wednesday"]

# %%
my_df=pd.DataFrame(my_data,my_rows,my_columns)
my_df
# Out:
#      Monday   Tuesday  Wednesday
# A  0.272590  0.272800   0.751906
# B  0.847827  0.214254   0.958457
# C  0.488043  0.018803   0.143007
# D  0.508260  0.350070   0.191650

# %% [markdown]
# Importing csv file

# %% [markdown]
# Importing csv file form google drive

# %% [markdown]
# Importing csv file from local system

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b1bdb15-e83b-4d41-83d6-6d7a980749e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b1bdb15-e83b-4d41-83d6-6d7a980749e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
my_df3=pd.read_csv('sim-companies-account-history-Orbia Corporations ltd..csv')
my_df3
# Out:
#              id                         Timestamp    Category  Money  \
# 0    2298740861  2025-04-29T09:42:18.261736+00:00  production  -1155
# 1    2298740304  2025-04-29T09:41:39.466536+00:00       sales  10649
# 2    2298740299  2025-04-29T09:41:38.907093+00:00       sales  11779
# 3    2298740271  2025-04-29T09:41:37.686576+00:00       sales  10685
# 4    2298302488  2025-04-29T00:08:59.481045+00:00    interest   -225
# ..          ...                               ...         ...    ...
# 654  2260630673  2025-04-01T11:51:35.449936+00:00       sales    254
# 655  2260630205  2025-04-01T11:50:44.495016+00:00  production    -26
# 656  2260629986  2025-04-01T11:50:06.698564+00:00      market    -15
# 657  2260629963  2025-04-01T11:49:58.979953+00:00      market    -59
# 658  2260629274  2025-04-01T11:47:41.304730+00:00        game    500
#
#                 Description                                            Details
# ...

# %% [markdown]
# pulling out rows

# %%
my_df3.loc[0]
# Out:
# id                                                   2298740861
# Timestamp                      2025-04-29T09:42:18.261736+00:00
# Category                                             production
# Money                                                     -1155
# Description                              Production of Displays
# Details        {"price": "$88.86", "quality": 0, "amount": 100}
# Name: 0, dtype: object

# %% [markdown]
# pulling out multiple rows

# %%
my_df3.loc[[0,5]]
# Out:
#            id                         Timestamp    Category  Money  \
# 0  2298740861  2025-04-29T09:42:18.261736+00:00  production  -1155
# 5  2298270246  2025-04-29T00:07:54.996072+00:00    interest   -425
#
#               Description                                            Details
# 0  Production of Displays   {"price": "$88.86", "quality": 0, "amount": 100}
# 5   Bond interest payment  {"bond value": "$85000", "interest": "0.5%", "...

# %% [markdown]
# Grabbing the first 'n' rows
#
# data_frame_name.head(n)

# %%
my_df3.head(10)
# Out:
#            id                         Timestamp    Category  Money  \
# 0  2298740861  2025-04-29T09:42:18.261736+00:00  production  -1155
# 1  2298740304  2025-04-29T09:41:39.466536+00:00       sales  10649
# 2  2298740299  2025-04-29T09:41:38.907093+00:00       sales  11779
# 3  2298740271  2025-04-29T09:41:37.686576+00:00       sales  10685
# 4  2298302488  2025-04-29T00:08:59.481045+00:00    interest   -225
# 5  2298270246  2025-04-29T00:07:54.996072+00:00    interest   -425
# 6  2298268580  2025-04-29T00:07:52.044084+00:00    interest   -425
# 7  2298264817  2025-04-29T00:07:45.491751+00:00    interest   -375
# 8  2298259869  2025-04-29T00:07:37.266021+00:00    interest   -160
# 9  2298253756  2025-04-29T00:07:27.285035+00:00    interest   -225
#
#               Description                                            Details
# 0  Production of Displays   {"price": "$88.86", "quality": 0, "amount": 100}
# ...

# %% [markdown]
# Grabbing the last 'n' rows
#
# data_frame_name.tail(n)

# %%
my_df3.tail(10)
# Out:
#              id                         Timestamp    Category  Money  \
# 649  2260633052  2025-04-01T11:58:10.435589+00:00      market   -154
# 650  2260632427  2025-04-01T11:56:20.646383+00:00      market  -1750
# 651  2260632112  2025-04-01T11:55:21.008184+00:00        game     50
# 652  2260632065  2025-04-01T11:55:13.755321+00:00        game  12000
# 653  2260631858  2025-04-01T11:54:33.634259+00:00      market   -480
# 654  2260630673  2025-04-01T11:51:35.449936+00:00       sales    254
# 655  2260630205  2025-04-01T11:50:44.495016+00:00  production    -26
# 656  2260629986  2025-04-01T11:50:06.698564+00:00      market    -15
# 657  2260629963  2025-04-01T11:49:58.979953+00:00      market    -59
# 658  2260629274  2025-04-01T11:47:41.304730+00:00        game    500
#
#                          Description  \
# 649           Bought Seeds on market
# 650        Bought Software on market
# 651           Achievement - Retailer
# 652  Achievement - Tutorial Finished
# ...

# %% [markdown]
# Leaving the parameters empty in the .head() and .tail() prints the first and the last 5 rows

# %% [markdown]
# data_frame_name.info() gives the information about the data frame

# %%
my_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659 entries, 0 to 658
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           659 non-null    int64
#  1   Timestamp    659 non-null    object
#  2   Category     659 non-null    object
#  3   Money        659 non-null    int64
#  4   Description  659 non-null    object
#  5   Details      659 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 31.0+ KB

# %% [markdown]
# Shape of the data frame

# %%
my_df3.shape
# Out:
# (659, 6)

# %% [markdown]
# Get info about the number of dimensions

# %%
my_df3.ndim
# Out:
# 2

# %%
my_df3.dtypes
# Out:
# id              int64
# Timestamp      object
# Category       object
# Money           int64
# Description    object
# Details        object
# dtype: object

# %% [markdown]
# Statistical Data

# %%
my_df3.describe()
# Out:
#                  id         Money
# count  6.590000e+02    659.000000
# mean   2.282896e+09     58.726859
# std    1.026374e+07  10058.923071
# min    2.260629e+09 -58328.000000
# 25%    2.279349e+09  -1458.000000
# 50%    2.283253e+09   -154.000000
# 75%    2.289750e+09   1474.500000
# max    2.298741e+09  85000.000000

# %%
my_df3['Money'].describe()
# Out:
# count      659.000000
# mean        58.726859
# std      10058.923071
# min     -58328.000000
# 25%      -1458.000000
# 50%       -154.000000
# 75%       1474.500000
# max      85000.000000
# Name: Money, dtype: float64

# %%
my_df3['Description'].describe()
# Out:
# count                       659
# unique                      116
# top       Sales of Smart phones
# freq                        121
# Name: Description, dtype: object

# %%
my_df3['Description']
# Out:
# 0      Production of Displays
# 1            Sales of Laptops
# 2        Sales of Televisions
# 3            Sales of Laptops
# 4       Bond interest payment
#                 ...
# 654           Sales of Apples
# 655      Production of Apples
# 656    Bought Seeds on market
# 657    Bought Water on market
# 658            Starting money
# Name: Description, Length: 659, dtype: object

# %% [markdown]
# Syntax:
#
# df_name.iloc[starting_index : ending_index, column_number]

# %%
my_df3.iloc[5:,5]
# Out:
# 5      {"bond value": "$85000", "interest": "0.5%", "...
# 6      {"bond value": "$85000", "interest": "0.5%", "...
# 7      {"bond value": "$75000", "interest": "0.5%", "...
# 8      {"bond value": "$20000", "interest": "0.8%", "...
# 9      {"bond value": "$45000", "interest": "0.5%", "...
#                              ...
# 654    {"action": "take", "building": {"id": 42693523...
# 655       {"price": "$2.00", "quality": 0, "amount": 50}
# 656    {"amount": 50, "price": "$0.30", "seller(s)": ...
# 657    {"amount": 150, "price": "$0.39", "seller(s)":...
# 658                                                   {}
# Name: Details, Length: 654, dtype: object

# %% [markdown]
# Counting Data

# %% [markdown]
# Counts number of distinct kind of data
#
# Syntax: df_name['Element'].value_count()

# %%
my_df3['Description'].value_counts()
# Out:
# Description
# Sales of Smart phones              121
# Bond interest payment               69
# Sales of Laptops                    61
# Sales of Underwear                  29
# Bought Chemicals on market          28
#                                   ...
# Production of Coffee beans           1
# Achievement - Tutorial Finished      1
# Bought Apples on market              1
# Production of Apples                 1
# Starting money                       1
# Name: count, Length: 116, dtype: int64

# %% [markdown]
# Finding the percentage(Normalizing)
#
# Syntax:df_name['Element'].value_counts(normalize=True)
#
# Percnetage value= Normalized value * 100

# %%
my_df3['Description'].value_counts(normalize=True)
# Out:
# Description
# Sales of Smart phones              0.183612
# Bond interest payment              0.104704
# Sales of Laptops                   0.092564
# Sales of Underwear                 0.044006
# Bought Chemicals on market         0.042489
#                                      ...
# Production of Coffee beans         0.001517
# Achievement - Tutorial Finished    0.001517
# Bought Apples on market            0.001517
# Production of Apples               0.001517
# Starting money                     0.001517
# Name: proportion, Length: 116, dtype: float64

# %% [markdown]
# Finding Count of some specific elements
#
# Syntax: df_name['Category'].value_counts()['Element']

# %%
my_df3['Description'].value_counts()['Sales of Laptops']
# Out:
# np.int64(61)

# %% [markdown]
# Group by size,count
#
# Syntax:
#
# df_name.groupby('Description').size()
#
# df_name.groupby('Description').color()

# %%
my_df3.groupby('Description').size()
# Out:
# Description
# A phone for your son                  1
# Achievement - Builder                 2
# Achievement - Buyer                   4
# Achievement - Chairman                2
# Achievement - Employer                3
#                                      ..
# Underwear market order filled         1
# Vegetables market order filled        1
# Wood market order filled              1
# Wood market order partially filled    2
# Workplace incident                    1
# Length: 116, dtype: int64

# %%
my_df3.groupby('Description').count()
# Out:
#                                     id  Timestamp  Category  Money  Details
# Description
# A phone for your son                 1          1         1      1        1
# Achievement - Builder                2          2         2      2        2
# Achievement - Buyer                  4          4         4      4        4
# Achievement - Chairman               2          2         2      2        2
# Achievement - Employer               3          3         3      3        3
# ...                                 ..        ...       ...    ...      ...
# Underwear market order filled        1          1         1      1        1
# Vegetables market order filled       1          1         1      1        1
# Wood market order filled             1          1         1      1        1
# Wood market order partially filled   2          2         2      2        2
# Workplace incident                   1          1         1      1        1
#
# [116 rows x 5 columns]

# %% [markdown]
# Add New Columns to Dataframes using pandas

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-deee058e-c2b4-4149-83f9-b949f1d3cb78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-deee058e-c2b4-4149-83f9-b949f1d3cb78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
my_df4=pd.read_csv('dog_data_short.csv')
my_df4
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
gender=["Male","Female","Female","Male","Male"]
my_df4["Gender"]=gender
my_df4
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238  Female
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139    Male

# %% [markdown]
# Adding default values

# %%
my_df4["Alive/Dead"]=['True']*len(my_df4)
my_df4
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male       True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female       True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  Female       True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male       True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139    Male       True

# %% [markdown]
# Adding NAN values

# %%
my_df4["Show dogs"]=[np.nan]*len(my_df4)
my_df4
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male       True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female       True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  Female       True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male       True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139    Male       True
#
#    Show dogs
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# Insert function
#
# Syntax:
#
# df_name.insert(column_position,"Column_Title,value*len(df))

# %%
my_df4.insert(1,"Adopted",['True']*len(my_df4))
my_df4
# Out:
#                  Breed Adopted        Color  DogName  OwnerZip  Gender  \
# 0             COCKAPOO    True        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD    True  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS    True      BRINDLE     EICH     15238  Female
# 3                MIXED    True  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER    True  WHITE/BROWN   OAKLEY     15139    Male
#
#   Alive/Dead  Show dogs
# 0       True        NaN
# 1       True        NaN
# 2       True        NaN
# 3       True        NaN
# 4       True        NaN

# %% [markdown]
# Assign function
#
# Syntax:
#
# new_df=df_name.assign(Column_Name=['Value']*len(df))

# %%
my_df5=my_df4.assign(Horse=['False']*len(my_df4))
my_df5
# Out:
#                  Breed Adopted        Color  DogName  OwnerZip  Gender  \
# 0             COCKAPOO    True        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD    True  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS    True      BRINDLE     EICH     15238  Female
# 3                MIXED    True  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER    True  WHITE/BROWN   OAKLEY     15139    Male
#
#   Alive/Dead  Show dogs  Horse
# 0       True        NaN  False
# 1       True        NaN  False
# 2       True        NaN  False
# 3       True        NaN  False
# 4       True        NaN  False
